# %% [markdown]
# # Dead time check for Mini-EUSO CPU files
#
# Compare the time stamps from L3 packets with the expected 5.24s readout time.

# %%
# %matplotlib inline
from raw_data_vis import *   
import seaborn as sns
sns.set_style("dark")

# %%
# Most recent data
filepath = "/Users/fran/Dropbox/EUSO/CPU/tor_vergata_dec2017/16122017/cleanroom_16122017/"
filename = filepath + "CPU_RUN_MAIN__2017_12_16__11_01_55.dat"
with DataVis(filename) as FileVis:
    FileVis.check_dead_time()

# %%
# File from October integration in Tor Vergata

filename = filepath + "CPU_RUN_MAIN__2017_12_16__10_46_36.dat"
#"CPU_RUN_MAIN__2017_12_16__10_37_47.dat"
with DataVis(filename) as FileVis:
    FileVis.check_dead_time()
